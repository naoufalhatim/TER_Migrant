# %%
import pandas as pd 
import numpy as np 
import re 

df1=pd.read_csv('F15_test.txt',sep='\t')
df2=pd.read_csv('Annotation_sentiment_pour_tests_1er_corpus_entier.txt', sep='\t')
df=df2
df.dropna(axis=1, how='all', inplace=True)

df.sort_values('Type', inplace=True)
df.drop_duplicates(subset=['Start','Stop'], keep='first', inplace=True)
df.sort_values('Id', inplace=True)

df['feat']=df.Features
df.Features=df.Features.str.replace('{','', regex=False).str.replace(' ', '', regex=False).str.replace('}','', regex=False)
df['Features']=df['Features'].apply(lambda x: x.split(','))
df.Features=df.Features.apply(lambda x : [v.split('=') for v in x])

def list_par(x,param):
    for y in x:
        if (y[0]==param):
            return y[1]
        else:
            pass
df['String']=df.Features[df['Type']=='Token'].apply(lambda x : list_par(x,'string'))
df['lenght']=df['Stop']-df['Start']

df['Sentiment']=df.Features[df['Type']=='Sentiment'].apply(lambda x : list_par(x,'polarité'))
df['Sent']=0
df['Sent'].loc[df.apply(lambda x: x['Sentiment']=='positif',axis=1)]=1
df['Sent'].loc[df.apply(lambda x: x['Sentiment']=='négatif',axis=1)]=-1

df['Kind']=df.Features[df['Type']=='Token'].apply(lambda x : list_par(x, 'kind'))

df=df[~(df['Kind']=='symbol')]
df[df['Kind']=='symbol']

df['Type'][df['Type']=='Geonames']='Location'
df['Type'][df['Type']=='BDNyme']='Location'
# Out:
# C:\Users\adminetu\Anaconda3\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\adminetu\Anaconda3\lib\site-packages\ipykernel_launcher.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\adminetu\Anaconda3\lib\site-packages\pandas\core\generic.py:7626: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# C:\Users\adminetu\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3267: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Users\adminetu\Anaconda3\lib\site-packages\ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df
# Out:
#            Type  Start   Stop     Id  \
# 0         Token      0     13    236
# 1         Token     14     16    238
# 2         Token     16     18    239
# 3         Token     22     23    244
# 4         Token     23     24    245
# 5         Token     24     27    246
# 6         Token     28     30    248
# 7         Token     31     38    250
# 8         Token     39     40    252
# 9         Token     41     48    254
# 10        Token     48     49    255
# 11        Token     49     50    256
# 12        Token     69     74    272
# 13        Token     82     84    279
# 14        Token     85     89    281
# 15        Token     90     95    283
# 16        Token     96     98    285
# 17        Token     99    107    287
# 18        Token    108    112    289
# 19        Token    119    123    295
# 20        Token    131    133    302
# 21        Token    134    136    304
# 22        Token    137    145    306
# 23        Token    146    148    308
# 24        Token    155    160    314
# 25        Token    161    166    316
# 26        Token    167    174    318
# 27        Token    175    179    320
# 28        Token    209    211    339
# 29        Token    211    212    340
# ...         ...    ...    ...    ...
# 6686  Sentiment  46387  46394  32598
# 6695  Sentiment  46468  46476  32599
# 6699  Sentiment  46503  46511  32600
# 6705  Sentiment  46542  46553  32601
# 6731  Sentiment  46733  46751  32603
# 6750  Sentiment  46874  46881  32604
# 6758  Sentiment  46909  46919  32605
# 6789  Sentiment  47182  47189  32606
# 6861  Sentiment  47762  47777  32607
# 6875  Sentiment  47905  47919  32608
# 6938  Sentiment  48396  48406  32609
# 6945  Sentiment  48446  48456  32610
# 7031  Sentiment  49095  49105  32611
# 7034  Sentiment  49135  49142  32612
# 7040  Sentiment  49193  49200  32613
# 7061  Sentiment  49302  49308  32614
# 7066  Sentiment  49323  49329  32615
# 7074  Sentiment  49386  49392  32616
# 7078  Sentiment  49415  49421  32617
# 7089  Sentiment  49496  49507  32618
# 7127  Sentiment  49752  49761  32619
# 7158  Sentiment  49976  49987  32620
# 7179  Sentiment  50127  50138  32621
# 7183  Sentiment  50162  50176  32622
# 7203  Sentiment  50305  50311  32623
# 7205  Sentiment  50325  50334  32624
# 7247  Sentiment  50528  50538  32625
# 7317  Sentiment  51098  51107  32626
# 7390  Sentiment  51722  51727  32627
# 7426  Sentiment  52038  52046  32628
#
#                                                Features  \
# 0     [[kind, word], [length, 13], [orth, upperIniti...
# 1     [[kind, word], [length, 2], [orth, allCaps], [...
# 2           [[kind, number], [length, 2], [string, 14]]
# 3     [[kind, punctuation], [length, 1], [position, ...
# 4     [[kind, punctuation], [length, 1], [position, ...
# 5     [[kind, word], [length, 3], [orth, lowercase],...
# 6     [[kind, word], [length, 2], [orth, lowercase],...
# 7     [[kind, word], [length, 7], [orth, lowercase],...
# 8     [[kind, word], [length, 1], [orth, lowercase],...
# 9     [[kind, word], [length, 7], [orth, lowercase],...
# 10    [[kind, punctuation], [length, 1], [position, ...
# 11    [[kind, punctuation], [length, 1], [position, ...
# 12    [[kind, word], [length, 5], [orth, lowercase],...
# 13    [[kind, word], [length, 2], [orth, lowercase],...
# 14    [[kind, word], [length, 4], [orth, lowercase],...
# 15    [[kind, word], [length, 5], [orth, lowercase],...
# 16    [[kind, word], [length, 2], [orth, lowercase],...
# 17    [[kind, word], [length, 8], [orth, lowercase],...
# 18    [[kind, word], [length, 4], [orth, lowercase],...
# 19    [[kind, word], [length, 4], [orth, lowercase],...
# 20    [[kind, word], [length, 2], [orth, lowercase],...
# 21    [[kind, word], [length, 2], [orth, lowercase],...
# 22    [[kind, word], [length, 8], [orth, lowercase],...
# 23    [[kind, word], [length, 2], [orth, lowercase],...
# 24    [[kind, word], [length, 5], [orth, lowercase],...
# 25    [[kind, word], [length, 5], [orth, lowercase],...
# 26    [[kind, word], [length, 7], [orth, lowercase],...
# 27    [[kind, word], [length, 4], [orth, lowercase],...
# 28    [[kind, word], [length, 2], [orth, lowercase],...
# 29      [[kind, punctuation], [length, 1], [string, _]]
# ...                                                 ...
# 6686                              [[polarité, positif]]
# 6695                              [[polarité, négatif]]
# 6699                              [[polarité, négatif]]
# 6705                              [[polarité, négatif]]
# 6731                              [[polarité, positif]]
# 6750                              [[polarité, positif]]
# 6758                              [[polarité, négatif]]
# 6789                              [[polarité, négatif]]
# 6861                              [[polarité, négatif]]
# 6875                              [[polarité, positif]]
# 6938                              [[polarité, négatif]]
# 6945                              [[polarité, négatif]]
# 7031                              [[polarité, positif]]
# 7034                              [[polarité, négatif]]
# 7040                              [[polarité, négatif]]
# 7061                              [[polarité, négatif]]
# 7066                              [[polarité, négatif]]
# 7074                              [[polarité, négatif]]
# 7078                              [[polarité, négatif]]
# 7089                              [[polarité, positif]]
# 7127                              [[polarité, négatif]]
# 7158                              [[polarité, positif]]
# 7179                              [[polarité, négatif]]
# 7183                              [[polarité, négatif]]
# 7203                              [[poalrité, négatif]]
# 7205                              [[polarité, négatif]]
# 7247                              [[polarité, négatif]]
# 7317                              [[polarité, négatif]]
# 7390                              [[polarité, positif]]
# 7426                              [[polarité, négatif]]
#
#                                                    feat         String  \
# 0     {kind=word, length=13, orth=upperInitial, stri...  Transcription
# 1        {kind=word, length=2, orth=allCaps, string=FR}             FR
# 2                    {kind=number, length=2, string=14}             14
# 3     {kind=punctuation, length=1, position=startpun...              [
# 4     {kind=punctuation, length=1, position=startpun...              [
# 5     {kind=word, length=3, orth=lowercase, string=pas}            pas
# 6      {kind=word, length=2, orth=lowercase, string=de}             de
# 7     {kind=word, length=7, orth=lowercase, string=d...        découpe
# 8       {kind=word, length=1, orth=lowercase, string=d}              d
# 9     {kind=word, length=7, orth=lowercase, string=e...        extrait
# 10    {kind=punctuation, length=1, position=endpunct...              ]
# 11    {kind=punctuation, length=1, position=endpunct...              ]
# 12    {kind=word, length=5, orth=lowercase, string=a...          alors
# 13     {kind=word, length=2, orth=lowercase, string=je}             je
# 14    {kind=word, length=4, orth=lowercase, string=f...           fais
# 15    {kind=word, length=5, orth=lowercase, string=c...          comme
# 16     {kind=word, length=2, orth=lowercase, string=la}             la
# 17    {kind=word, length=8, orth=lowercase, string=d...       dernière
# 18    {kind=word, length=4, orth=lowercase, string=f...           fois
# 19    {kind=word, length=4, orth=lowercase, string=h...           hein
# 20     {kind=word, length=2, orth=lowercase, string=je}             je
# 21     {kind=word, length=2, orth=lowercase, string=me}             me
# 22    {kind=word, length=8, orth=lowercase, string=p...       présente
# 23     {kind=word, length=2, orth=lowercase, string=et}             et
# 24    {kind=word, length=5, orth=lowercase, string=o...          ouais
# 25    {kind=word, length=5, orth=lowercase, string=a...          alors
# 26    {kind=word, length=7, orth=lowercase, string=a...        attends
# 27    {kind=word, length=4, orth=lowercase, string=h...           hein
# 28     {kind=word, length=2, orth=lowercase, string=ch}             ch
# 29               {kind=punctuation, length=1, string=_}              _
# ...                                                 ...            ...
# 6686                                 {polarité=positif}            NaN
# 6695                                 {polarité=négatif}            NaN
# 6699                                 {polarité=négatif}            NaN
# 6705                                 {polarité=négatif}            NaN
# 6731                                 {polarité=positif}            NaN
# 6750                                 {polarité=positif}            NaN
# 6758                                 {polarité=négatif}            NaN
# 6789                                 {polarité=négatif}            NaN
# 6861                                 {polarité=négatif}            NaN
# 6875                                 {polarité=positif}            NaN
# 6938                                 {polarité=négatif}            NaN
# 6945                                 {polarité=négatif}            NaN
# 7031                                 {polarité=positif}            NaN
# 7034                                 {polarité=négatif}            NaN
# 7040                                 {polarité=négatif}            NaN
# 7061                                 {polarité=négatif}            NaN
# 7066                                 {polarité=négatif}            NaN
# 7074                                 {polarité=négatif}            NaN
# 7078                                 {polarité=négatif}            NaN
# 7089                                 {polarité=positif}            NaN
# 7127                                 {polarité=négatif}            NaN
# 7158                                 {polarité=positif}            NaN
# 7179                                 {polarité=négatif}            NaN
# 7183                                 {polarité=négatif}            NaN
# 7203                                 {poalrité=négatif}            NaN
# 7205                                 {polarité=négatif}            NaN
# 7247                                 {polarité=négatif}            NaN
# 7317                                 {polarité=négatif}            NaN
# 7390                                 {polarité=positif}            NaN
# 7426                                 {polarité=négatif}            NaN
#
#       lenght Sentiment  Sent         Kind
# 0         13       NaN     0         word
# 1          2       NaN     0         word
# 2          2       NaN     0       number
# 3          1       NaN     0  punctuation
# 4          1       NaN     0  punctuation
# 5          3       NaN     0         word
# 6          2       NaN     0         word
# 7          7       NaN     0         word
# 8          1       NaN     0         word
# 9          7       NaN     0         word
# 10         1       NaN     0  punctuation
# 11         1       NaN     0  punctuation
# 12         5       NaN     0         word
# 13         2       NaN     0         word
# 14         4       NaN     0         word
# 15         5       NaN     0         word
# 16         2       NaN     0         word
# 17         8       NaN     0         word
# 18         4       NaN     0         word
# 19         4       NaN     0         word
# 20         2       NaN     0         word
# 21         2       NaN     0         word
# 22         8       NaN     0         word
# 23         2       NaN     0         word
# 24         5       NaN     0         word
# 25         5       NaN     0         word
# 26         7       NaN     0         word
# 27         4       NaN     0         word
# 28         2       NaN     0         word
# 29         1       NaN     0  punctuation
# ...      ...       ...   ...          ...
# 6686       7   positif     1          NaN
# 6695       8   négatif    -1          NaN
# 6699       8   négatif    -1          NaN
# 6705      11   négatif    -1          NaN
# 6731      18   positif     1          NaN
# 6750       7   positif     1          NaN
# 6758      10   négatif    -1          NaN
# 6789       7   négatif    -1          NaN
# 6861      15   négatif    -1          NaN
# 6875      14   positif     1          NaN
# 6938      10   négatif    -1          NaN
# 6945      10   négatif    -1          NaN
# 7031      10   positif     1          NaN
# 7034       7   négatif    -1          NaN
# 7040       7   négatif    -1          NaN
# 7061       6   négatif    -1          NaN
# 7066       6   négatif    -1          NaN
# 7074       6   négatif    -1          NaN
# 7078       6   négatif    -1          NaN
# 7089      11   positif     1          NaN
# 7127       9   négatif    -1          NaN
# 7158      11   positif     1          NaN
# 7179      11   négatif    -1          NaN
# 7183      14   négatif    -1          NaN
# 7203       6      None     0          NaN
# 7205       9   négatif    -1          NaN
# 7247      10   négatif    -1          NaN
# 7317       9   négatif    -1          NaN
# 7390       5   positif     1          NaN
# 7426       8   négatif    -1          NaN
#
# [7199 rows x 11 columns]

# %%
df.sort_values('Start')
# Out:
#        Type  Start   Stop     Id  \
# 0     Token      0     13    236
# 1     Token     14     16    238
# 2     Token     16     18    239
# 3     Token     22     23    244
# 4     Token     23     24    245
# 5     Token     24     27    246
# 6     Token     28     30    248
# 7     Token     31     38    250
# 8     Token     39     40    252
# 9     Token     41     48    254
# 10    Token     48     49    255
# 11    Token     49     50    256
# 12    Token     69     74    272
# 13    Token     82     84    279
# 14    Token     85     89    281
# 15    Token     90     95    283
# 16    Token     96     98    285
# 17    Token     99    107    287
# 18    Token    108    112    289
# 19    Token    119    123    295
# 20    Token    131    133    302
# 21    Token    134    136    304
# 22    Token    137    145    306
# 23    Token    146    148    308
# 24    Token    155    160    314
# 25    Token    161    166    316
# 26    Token    167    174    318
# 27    Token    175    179    320
# 28    Token    209    211    339
# 29    Token    211    212    340
# ...     ...    ...    ...    ...
# 7498  Token  52477  52482  24802
# 7499  Token  52483  52488  24804
# 7500  Token  52489  52495  24806
# 7501  Token  52496  52499  25316
# 7502  Token  52499  52501  24810
# 7503  Token  52502  52504  25317
# 7504  Token  52504  52509  24814
# 7505  Token  52510  52513  24816
# 7506  Token  52514  52524  24818
# 7507  Token  52539  52543  24828
# 7508  Token  52551  52552  24835
# 7509  Token  52553  52555  24837
# 7510  Token  52556  52559  24839
# 7511  Token  52560  52565  24841
# 7512  Token  52566  52570  24843
# 7513  Token  52571  52573  24845
# 7514  Token  52574  52580  24847
# 7515  Token  52581  52586  24849
# 7516  Token  52587  52590  24851
# 7517  Token  52591  52601  24853
# 7518  Token  52633  52634  24869
# 7519  Token  52634  52638  24870
# 7521  Token  52639  52641  24872
# 7522  Token  52641  52642  24873
# 7523  Token  52643  52645  24875
# 7524  Token  52646  52650  24877
# 7525  Token  52651  52653  24879
# 7526  Token  52654  52659  24881
# 7527  Token  52660  52665  24883
# 7528  Token  52666  52670  24885
#
#                                                Features  \
# 0     [[kind, word], [length, 13], [orth, upperIniti...
# 1     [[kind, word], [length, 2], [orth, allCaps], [...
# 2           [[kind, number], [length, 2], [string, 14]]
# 3     [[kind, punctuation], [length, 1], [position, ...
# 4     [[kind, punctuation], [length, 1], [position, ...
# 5     [[kind, word], [length, 3], [orth, lowercase],...
# 6     [[kind, word], [length, 2], [orth, lowercase],...
# 7     [[kind, word], [length, 7], [orth, lowercase],...
# 8     [[kind, word], [length, 1], [orth, lowercase],...
# 9     [[kind, word], [length, 7], [orth, lowercase],...
# 10    [[kind, punctuation], [length, 1], [position, ...
# 11    [[kind, punctuation], [length, 1], [position, ...
# 12    [[kind, word], [length, 5], [orth, lowercase],...
# 13    [[kind, word], [length, 2], [orth, lowercase],...
# 14    [[kind, word], [length, 4], [orth, lowercase],...
# 15    [[kind, word], [length, 5], [orth, lowercase],...
# 16    [[kind, word], [length, 2], [orth, lowercase],...
# 17    [[kind, word], [length, 8], [orth, lowercase],...
# 18    [[kind, word], [length, 4], [orth, lowercase],...
# 19    [[kind, word], [length, 4], [orth, lowercase],...
# 20    [[kind, word], [length, 2], [orth, lowercase],...
# 21    [[kind, word], [length, 2], [orth, lowercase],...
# 22    [[kind, word], [length, 8], [orth, lowercase],...
# 23    [[kind, word], [length, 2], [orth, lowercase],...
# 24    [[kind, word], [length, 5], [orth, lowercase],...
# 25    [[kind, word], [length, 5], [orth, lowercase],...
# 26    [[kind, word], [length, 7], [orth, lowercase],...
# 27    [[kind, word], [length, 4], [orth, lowercase],...
# 28    [[kind, word], [length, 2], [orth, lowercase],...
# 29      [[kind, punctuation], [length, 1], [string, _]]
# ...                                                 ...
# 7498  [[kind, word], [length, 5], [orth, lowercase],...
# 7499  [[kind, word], [length, 5], [orth, lowercase],...
# 7500  [[kind, word], [length, 6], [orth, lowercase],...
# 7501  [[kind, word], [length, 3], [orth, artapos], [...
# 7502  [[kind, word], [length, 2], [orth, lowercase],...
# 7503  [[kind, word], [length, 2], [orth, artapos], [...
# 7504  [[kind, word], [length, 5], [orth, lowercase],...
# 7505  [[kind, word], [length, 3], [orth, lowercase],...
# 7506  [[kind, word], [length, 10], [orth, lowercase]...
# 7507  [[kind, word], [length, 4], [orth, lowercase],...
# 7508  [[kind, word], [length, 1], [orth, lowercase],...
# 7509  [[kind, word], [length, 2], [orth, lowercase],...
# 7510  [[kind, word], [length, 3], [orth, lowercase],...
# 7511  [[kind, word], [length, 5], [orth, lowercase],...
# 7512  [[kind, word], [length, 4], [orth, lowercase],...
# 7513  [[kind, word], [length, 2], [orth, lowercase],...
# 7514  [[kind, word], [length, 6], [orth, lowercase],...
# 7515  [[kind, word], [length, 5], [orth, lowercase],...
# 7516  [[kind, word], [length, 3], [orth, lowercase],...
# 7517  [[kind, word], [length, 10], [orth, lowercase]...
# 7518  [[kind, punctuation], [length, 1], [position, ...
# 7519  [[kind, word], [length, 4], [orth, lowercase],...
# 7521  [[kind, word], [length, 2], [orth, lowercase],...
# 7522  [[kind, punctuation], [length, 1], [position, ...
# 7523  [[kind, word], [length, 2], [orth, lowercase],...
# 7524  [[kind, word], [length, 4], [orth, lowercase],...
# 7525  [[kind, word], [length, 2], [orth, lowercase],...
# 7526  [[kind, word], [length, 5], [orth, lowercase],...
# 7527  [[kind, word], [length, 5], [orth, lowercase],...
# 7528  [[kind, word], [length, 4], [orth, lowercase],...
#
#                                                    feat         String  \
# 0     {kind=word, length=13, orth=upperInitial, stri...  Transcription
# 1        {kind=word, length=2, orth=allCaps, string=FR}             FR
# 2                    {kind=number, length=2, string=14}             14
# 3     {kind=punctuation, length=1, position=startpun...              [
# 4     {kind=punctuation, length=1, position=startpun...              [
# 5     {kind=word, length=3, orth=lowercase, string=pas}            pas
# 6      {kind=word, length=2, orth=lowercase, string=de}             de
# 7     {kind=word, length=7, orth=lowercase, string=d...        découpe
# 8       {kind=word, length=1, orth=lowercase, string=d}              d
# 9     {kind=word, length=7, orth=lowercase, string=e...        extrait
# 10    {kind=punctuation, length=1, position=endpunct...              ]
# 11    {kind=punctuation, length=1, position=endpunct...              ]
# 12    {kind=word, length=5, orth=lowercase, string=a...          alors
# 13     {kind=word, length=2, orth=lowercase, string=je}             je
# 14    {kind=word, length=4, orth=lowercase, string=f...           fais
# 15    {kind=word, length=5, orth=lowercase, string=c...          comme
# 16     {kind=word, length=2, orth=lowercase, string=la}             la
# 17    {kind=word, length=8, orth=lowercase, string=d...       dernière
# 18    {kind=word, length=4, orth=lowercase, string=f...           fois
# 19    {kind=word, length=4, orth=lowercase, string=h...           hein
# 20     {kind=word, length=2, orth=lowercase, string=je}             je
# 21     {kind=word, length=2, orth=lowercase, string=me}             me
# 22    {kind=word, length=8, orth=lowercase, string=p...       présente
# 23     {kind=word, length=2, orth=lowercase, string=et}             et
# 24    {kind=word, length=5, orth=lowercase, string=o...          ouais
# 25    {kind=word, length=5, orth=lowercase, string=a...          alors
# 26    {kind=word, length=7, orth=lowercase, string=a...        attends
# 27    {kind=word, length=4, orth=lowercase, string=h...           hein
# 28     {kind=word, length=2, orth=lowercase, string=ch}             ch
# 29               {kind=punctuation, length=1, string=_}              _
# ...                                                 ...            ...
# 7498  {kind=word, length=5, orth=lowercase, string=é...          était
# 7499  {kind=word, length=5, orth=lowercase, string=r...          rendu
# 7500  {kind=word, length=6, orth=lowercase, string=c...         compte
# 7501    {kind=word, length=3, orth=artapos, string=qu'}            qu'
# 7502   {kind=word, length=2, orth=lowercase, string=il}             il
# 7503     {kind=word, length=2, orth=artapos, string=n'}             n'
# 7504  {kind=word, length=5, orth=lowercase, string=é...          était
# 7505  {kind=word, length=3, orth=lowercase, string=pas}            pas
# 7506  {kind=word, length=10, orth=lowercase, string=...     cordonnier
# 7507  {kind=word, length=4, orth=lowercase, string=m...           mais
# 7508    {kind=word, length=1, orth=lowercase, string=à}              à
# 7509   {kind=word, length=2, orth=lowercase, string=la}             la
# 7510  {kind=word, length=3, orth=lowercase, string=fin}            fin
# 7511  {kind=word, length=5, orth=lowercase, string=q...          quand
# 7512  {kind=word, length=4, orth=lowercase, string=m...           même
# 7513   {kind=word, length=2, orth=lowercase, string=il}             il
# 7514  {kind=word, length=6, orth=lowercase, string=s...         savait
# 7515  {kind=word, length=5, orth=lowercase, string=f...          faire
# 7516  {kind=word, length=3, orth=lowercase, string=les}            les
# 7517  {kind=word, length=10, orth=lowercase, string=...     chaussures
# 7518  {kind=punctuation, length=1, position=startpun...              [
# 7519  {kind=word, length=4, orth=lowercase, string=p...           pron
# 7521   {kind=word, length=2, orth=lowercase, string=pi}             pi
# 7522  {kind=punctuation, length=1, position=endpunct...              ]
# 7523   {kind=word, length=2, orth=lowercase, string=au}             au
# 7524  {kind=word, length=4, orth=lowercase, string=b...           bout
# 7525   {kind=word, length=2, orth=lowercase, string=du}             du
# 7526  {kind=word, length=5, orth=lowercase, string=t...          temps
# 7527  {kind=word, length=5, orth=lowercase, string=q...          quand
# 7528  {kind=word, length=4, orth=lowercase, string=m...           même
#
#       lenght Sentiment  Sent         Kind
# 0         13       NaN     0         word
# 1          2       NaN     0         word
# 2          2       NaN     0       number
# 3          1       NaN     0  punctuation
# 4          1       NaN     0  punctuation
# 5          3       NaN     0         word
# 6          2       NaN     0         word
# 7          7       NaN     0         word
# 8          1       NaN     0         word
# 9          7       NaN     0         word
# 10         1       NaN     0  punctuation
# 11         1       NaN     0  punctuation
# 12         5       NaN     0         word
# 13         2       NaN     0         word
# 14         4       NaN     0         word
# 15         5       NaN     0         word
# 16         2       NaN     0         word
# 17         8       NaN     0         word
# 18         4       NaN     0         word
# 19         4       NaN     0         word
# 20         2       NaN     0         word
# 21         2       NaN     0         word
# 22         8       NaN     0         word
# 23         2       NaN     0         word
# 24         5       NaN     0         word
# 25         5       NaN     0         word
# 26         7       NaN     0         word
# 27         4       NaN     0         word
# 28         2       NaN     0         word
# 29         1       NaN     0  punctuation
# ...      ...       ...   ...          ...
# 7498       5       NaN     0         word
# 7499       5       NaN     0         word
# 7500       6       NaN     0         word
# 7501       3       NaN     0         word
# 7502       2       NaN     0         word
# 7503       2       NaN     0         word
# 7504       5       NaN     0         word
# 7505       3       NaN     0         word
# 7506      10       NaN     0         word
# 7507       4       NaN     0         word
# 7508       1       NaN     0         word
# 7509       2       NaN     0         word
# 7510       3       NaN     0         word
# 7511       5       NaN     0         word
# 7512       4       NaN     0         word
# 7513       2       NaN     0         word
# 7514       6       NaN     0         word
# 7515       5       NaN     0         word
# 7516       3       NaN     0         word
# 7517      10       NaN     0         word
# 7518       1       NaN     0  punctuation
# 7519       4       NaN     0         word
# 7521       2       NaN     0         word
# 7522       1       NaN     0  punctuation
# 7523       2       NaN     0         word
# 7524       4       NaN     0         word
# 7525       2       NaN     0         word
# 7526       5       NaN     0         word
# 7527       5       NaN     0         word
# 7528       4       NaN     0         word
#
# [7199 rows x 11 columns]
